# %% [markdown]
# # HW1
#
# It's highly recommended to write solutions in markdown cells just in this notebook. If you do so, you'll get up to $1$ bonus point depending on how accurate and neat your work is. You can also write the solutions to math problems by hand and then send photos of them, but there will be no bonus in such case. If you are not familiar with LaTeX, see a 2-page [cheat sheet](http://tug.ctan.org/info/undergradmath/undergradmath.pdf) for a quick start.
#
# ## Task 1.1 (1 point)
#
# Give an example of two symmetric matrices whose product is not symmetric.
#
# ### YOUR SOLUTION HERE
# Let $\boldsymbol A$ and $\boldsymbol B$ $\in \mathbb R^{2\times 2}$
#
# $$
# \boldsymbol A = \begin{pmatrix} 2 & 1 \\ 1 & 3 \end{pmatrix}, \space \boldsymbol B = \begin{pmatrix} 3 & 0 \\ 0 & 2 \end{pmatrix}
# $$
#
# $\boldsymbol A^\top = \begin{pmatrix} 2 & 1 \\ 1 & 3 \end{pmatrix}, \space \boldsymbol B^\top = \begin{pmatrix} 3 & 0 \\ 0 & 2 \end{pmatrix} => \space \boldsymbol A \space and \space \boldsymbol B \space are \space symmetric$
#
# $\boldsymbol C  = \boldsymbol A \times \boldsymbol B  = \begin{pmatrix} (2\times3+1\times0) & (2\times0+1\times2) \\ (1\times3+3\times0) & (1\times0+3\times2) \end{pmatrix}$ = $\begin{pmatrix}6 & 2 \\ 3 & 6 \end{pmatrix}$
#
# $\boldsymbol C^\top = \begin{pmatrix}6 & 3 \\ 2 & 6 \end{pmatrix}$
#
# $\boldsymbol C \neq \boldsymbol C^\top => \space \boldsymbol C \space is \space nonsymmetric$

# %% [markdown]
# ## Task 1.2 (2 points)
#
# **Sherman—Morrison formula**. Let $\boldsymbol A \in \mathbb R^{n\times n}$ be an invertible matrix and $\boldsymbol u, \boldsymbol v \in \mathbb R^n$. Prove that
#
# $$
#     (\boldsymbol A + \boldsymbol u \boldsymbol v^\top)^{-1} =
#     \boldsymbol A^{-1} - \frac{\boldsymbol A^{-1} \boldsymbol u \boldsymbol v^\top \boldsymbol A^{-1}}{1 + \boldsymbol v^\top\boldsymbol A^{-1} \boldsymbol u }.
# $$
#
# ### YOUR SOLUTION HERE
# $\begin{align*}(\boldsymbol A + \boldsymbol u \boldsymbol v^\top)^{-1}(\boldsymbol A + \boldsymbol u \boldsymbol v^\top) = \boldsymbol A^{-1}(\boldsymbol A + \boldsymbol u \boldsymbol v^\top) - \frac{\boldsymbol A^{-1} \boldsymbol u \boldsymbol v^\top \boldsymbol A^{-1}(\boldsymbol A + \boldsymbol{u v^\top})}{1 + \boldsymbol v^\top\boldsymbol A^{-1} \boldsymbol u}\end{align*}$
#
#
# $\begin{align*}\boldsymbol I = \boldsymbol I + \boldsymbol{A^{-1}uv^\top} - \frac{\boldsymbol{A^{-1}uv^\top - \boldsymbol{A^{-1}uv^\top}}\boldsymbol{A^{-1}uv^\top}}{1 + \boldsymbol v^\top \boldsymbol{A^{-1}u}}\end{align*}$
#
#
# $\begin{align*}\boldsymbol I = \boldsymbol I + \boldsymbol{A^{-1}uv^\top} - \frac{\boldsymbol{A^{-1}u (\boldsymbol{v^\top}} + \boldsymbol v^\top \boldsymbol{A^{-1}uv^\top})}{1 + \boldsymbol v^\top \boldsymbol{A^{-1}u}}\end{align*}$
#
#
# $\begin{align*}\boldsymbol I = \boldsymbol I + \boldsymbol{A^{-1}uv^\top} - \frac{\boldsymbol{A^{-1}u} \bcancel{(1 + \boldsymbol v^\top \boldsymbol{A^{-1}u})}\boldsymbol v^\top}{\bcancel{1 + \boldsymbol v^\top \boldsymbol{A^{-1}u}}}\end{align*}$
#
#
# $\begin{align*}\boldsymbol I = \boldsymbol I + \bcancel{\boldsymbol{A^{-1}uv^\top}} - \bcancel{\boldsymbol{A^{-1}uv^\top}}\end{align*}$
#
# $\begin{align*}\boldsymbol I = \boldsymbol I\end{align*}$

# %% [markdown]
# ## Task 1.3 (1 point)
#
# Simplify the expression
#
# $$
#         \det\big(\boldsymbol {AXB} (\boldsymbol C^{-\top} \boldsymbol X^{\top} \boldsymbol C)^\top\big)^{-\top}
# $$
#
# if $\boldsymbol A,\boldsymbol B, \boldsymbol C, \boldsymbol X \in \mathbb R^{n\times n}$, $\det \boldsymbol C \ne 0$ and $\det (\boldsymbol C^{-\top} \boldsymbol X^{\top} \boldsymbol C) \ne 0$.
#
# ### YOUR SOLUTION HERE
# $\begin{align*}\det(\boldsymbol{AXBC^{-1}XC})^{-1}\end{align*}$
#
# $\begin{align*}\frac{\bcancel{\det(\boldsymbol C)}}{\det(\boldsymbol{AX^{2}B}) \times \bcancel{\det(\boldsymbol C)}}\end{align*}$
#
# $\begin{align*}\frac{1}{\det(\boldsymbol{AX^{2}B})}\end{align*}$

# %% [markdown]
# ## Task 1.4
#
# Let $\boldsymbol A \in \mathbb R^{n\times n}$ be a symmetric positive definite matrix and
#
# $$
# f(\boldsymbol x) = \frac{\boldsymbol x^\top \boldsymbol{Ax}}{\boldsymbol x^\top \boldsymbol x}, \quad \boldsymbol x \in \mathbb R^n.
# $$
#
# (a) (**2 points**) Calculate $\nabla f(\boldsymbol x)$ and prove that $\nabla f(\boldsymbol x) = \boldsymbol 0$ iff $\boldsymbol x$ is an eigenvector of $\boldsymbol A$.
#
# (b) (**1 point**) Prove that
#
# $$
# \max\limits_{\boldsymbol x \ne \boldsymbol 0} f(\boldsymbol x) = \lambda_{\max}(\boldsymbol A), \quad
# \min\limits_{\boldsymbol x \ne \boldsymbol 0} f(\boldsymbol x) = \lambda_{\min}(\boldsymbol A)
# $$
#
# (c) (**bonus! up to 4 points**) Find $\nabla^2 f(\boldsymbol x)$. Also show that $\nabla^2 f(\boldsymbol x_{\min})$ is (semi)positive definite and  $\nabla^2 f(\boldsymbol x_{\max})$ is (semi)negative definite, where
#
# $$
#     \boldsymbol {Ax}_{\min} = \lambda_{\min} \boldsymbol x_{\min}, \quad \boldsymbol {Ax}_{\max} = \lambda_{\max} \boldsymbol x_{\max}.
# $$
#
# ### YOUR SOLUTION HERE
# $\begin{align*}\boldsymbol{(a)} \space \nabla f(\boldsymbol x) = \frac{\cfrac{\partial (\boldsymbol x^\top \boldsymbol{Ax})}{\partial \boldsymbol x} \times \boldsymbol x^\top \boldsymbol x - \boldsymbol x^\top \boldsymbol{Ax} \times \cfrac{\partial (\boldsymbol x^\top \boldsymbol x)}{\partial \boldsymbol x}}{(\boldsymbol x^\top \boldsymbol x)^{2}}\end{align*}$
#
# $\begin{align*}\boldsymbol x^\top \boldsymbol x = \begin{pmatrix}\boldsymbol x_{1} & \boldsymbol x_{2} & ... & \boldsymbol x_{n} \end{pmatrix} \times \begin{pmatrix}\boldsymbol x_{1} \\ \boldsymbol x_{2} \\ ... \\ \boldsymbol x_{n} \end{pmatrix} = \boldsymbol (x_{1})^{2} + \boldsymbol (x_{2})^{2} + ... + \boldsymbol (x_{n})^{2} \end{align*}$
#
# $\begin{align*}\frac{\partial (\boldsymbol x^\top \boldsymbol A \boldsymbol x)}{\partial \boldsymbol x} = 2 \boldsymbol x^\top \boldsymbol A \end{align*}$
#
# $\begin{align*} \nabla f(\boldsymbol x) = \frac{2 \boldsymbol x^\top \boldsymbol A \times \boldsymbol x^\top \boldsymbol x - \boldsymbol x^\top \boldsymbol{Ax} \times 2 \boldsymbol x^\top}{(\boldsymbol x^\top \boldsymbol x)^{2}} = \frac{\boldsymbol x^\top \boldsymbol x \times 2 \boldsymbol x^\top \boldsymbol A - \boldsymbol x^\top \boldsymbol{Ax} \times 2 \boldsymbol x^\top}{(\boldsymbol x^\top \boldsymbol x)^{2}} = 0 \end{align*}$
#
# $\begin{align*}\boldsymbol{Ax} = \boldsymbol{\lambda x} \end{align*}$
#
# $\begin{align*}\nabla f(\boldsymbol x) = \frac{2 \boldsymbol x^\top \boldsymbol A \times \boldsymbol x^\top \boldsymbol x - \boldsymbol x^\top \boldsymbol{Ax} \times 2 \boldsymbol x^\top}{(\boldsymbol x^\top \boldsymbol x)^{2}} = \frac{2 \boldsymbol x^\top \times \boldsymbol x^\top \boldsymbol {Ax} - \boldsymbol x^\top \boldsymbol{Ax} \times 2 \boldsymbol x^\top}{(\boldsymbol x^\top \boldsymbol x)^{2}} = \frac{2 \boldsymbol x^\top \times \boldsymbol x^\top \boldsymbol {\lambda x} - \boldsymbol x^\top \boldsymbol{\lambda x} \times 2 \boldsymbol x^\top}{(\boldsymbol x^\top \boldsymbol x)^{2}} = 0\end{align*}$
#
# $\begin{align*}\boldsymbol{(b)} \space f(\boldsymbol x) = \frac{\boldsymbol x_{i}^\top \boldsymbol{A_{i} x_{i}}}{\boldsymbol x_{i}^\top \boldsymbol x_{i}} = \boldsymbol \lambda_{i} \end{align*}$
#
# $\begin{align*} \boldsymbol x_{i}^\top \boldsymbol{A_{i} x_{i}} = \boldsymbol \lambda_{i} \boldsymbol x_{i}^\top \boldsymbol x_{i} \end{align*}$
#
# $\begin{align*} \boldsymbol{v} = \boldsymbol x_{i}^\top \boldsymbol x_{i} => \boldsymbol{Av} = \boldsymbol{\lambda v} \end{align*}$
#
# $\begin{align*} \boldsymbol{Av} = \boldsymbol{\lambda v}\end{align*}$
#
# $\begin{align*} f(\boldsymbol x) = \frac{\boldsymbol x_{i}^\top \boldsymbol{A_{i} x_{i}}}{\boldsymbol x_{i}^\top \boldsymbol x_{i}} =  \frac{\boldsymbol x_{i}^\top \boldsymbol{\lambda_{i} x_{i}}}{\boldsymbol x_{i}^\top \boldsymbol x_{i}} = \frac{\boldsymbol \lambda_{i} \bcancel{\boldsymbol x_{i}^\top \boldsymbol{x_{i}}}}{\bcancel{\boldsymbol x_{i}^\top \boldsymbol x_{i}}} = \boldsymbol \lambda_{i} \end{align*}$

# %% [markdown]
# ## Task 1.5 (programming, 2 points)
#
# Compare the performance of matrix-vector multiplication
#
# $$
#         \boldsymbol {Ax}, \quad \boldsymbol A \in \mathbb R^{n\times n}, \quad \boldsymbol x \in \mathbb R^n,
# $$
#
# in pure Python and in NumPy. Plot a graph of the execution time versus $n$ (see example below for the inner product of two vectors).

# %%
## YOUR CODE HERE

# %%
import numpy as np
import timeit
import matplotlib.pyplot as plt

# %matplotlib inline

# Value for dimensions
n = 1000

# For Numpy example with 3x3 matrices and 3x1 vectors multiplication
A = np.random.randint(5, size=(3, 3))
x = np.random.randint(5, size=(3, 1))

print(f"Example for 3x3 matrix and 3x1 vector: \nMatrix A: \n{A} \nvector x: \n{x}\n\n")

# For pure Python example with 3x3 matrices and 3x1 vectors multiplication
A_list = A.tolist()
x_list = x.tolist()
b_list = []

def purePyMult(A_list, x_list: list, size: int):
    temp = 0

    for i in range(size):
        for j in range(size):
            temp += A_list[i][j] * x_list[j][0]
        b_list.append(temp)
        temp = 0
    return b_list


def numPyMult(A, x: np.ndarray):
    return np.dot(A, x)


# For comparing results of 3x3 matrix and 3x1 vector with Python and Numpy
def printRes():
    b_list = purePyMult(A_list, x_list, 3)
    b = numPyMult(A, x)
    
    print(f"Python result: \n{b_list} \nNumpy result: \n{b}\n")
        

# Getting the lists filled with execution times
def getExecTimes(n):
    
    pyTimeList = []
    npTimeList = []

    for i in range(1, n+1):
        # Increasing the matrix and vector sizes
        A = np.random.randint(100, size=(i, i))
        x = np.random.randint(100, size=(i, 1))
        A_list = A.tolist()
        x_list = x.tolist()

        start = timeit.default_timer()
        b_list = purePyMult(A_list, x_list, i)
        end = timeit.default_timer()
        pyTimeList.append(end-start)

        start = timeit.default_timer()
        b = numPyMult(A, x)
        end = timeit.default_timer()
        npTimeList.append(end-start)

    return pyTimeList, npTimeList

printRes()
pyTimeList, npTimeList = getExecTimes(n)

# Plotting (may take some time, change n in case you are tired of waiting)
plt.plot(np.arange(1, n+1), pyTimeList, c='r', lw=2, label="py")
plt.plot(np.arange(1, n+1), npTimeList, c='b', lw=2, label="np")
plt.xlim(1, n)
plt.xlabel("Size")
plt.ylabel("Time (s)")
plt.legend()
plt.title("Matrix-Vector Multiplication: Python vs NumPy")
plt.grid(ls=":")
plt.show()
# Out:
# Example for 3x3 matrix and 3x1 vector:
# Matrix A:
# [[4 3 4]
#  [2 0 3]
#  [3 2 3]]
# vector x:
# [[4]
#  [4]
#  [0]]
#
#
# Python result:
# [28, 8, 20]
# Numpy result:
# [[28]
#  [ 8]
#  [20]]

# %% [markdown]
# ## Demo for task 1.5: dot product performance

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %config InlineBackend.figure_format = 'svg'


def python_inner(a, b: np.array):
    return sum(a * b)

        
def measure_time(func, size, n_samples=1):
    result = np.zeros(n_samples)
    for i in range(n_samples):
        begin = time()
        func(np.random.randn(size), np.random.randn(size))
        result[i] = time() - begin
    return result.mean()
    

def check_correctness(func, max_size, attempts=10):
    for size in range(1, max_size + 1):
        for _ in range(attempts):
            a = np.random.randn(size)
            b = np.random.randn(size)
            assert np.allclose(func(a, b), np.dot(a, b)), f"different values for {a} and {b}"
    

def get_times_lists(func, step=20, max_size=1000, n_samples=20):
    py_times = []
    np_times = []
    sizes = np.arange(20, max_size + 1, 20)
    for size in sizes:
        py_times.append(measure_time(func, size))
        np_times.append(measure_time(np.dot, size))
    return np.array(py_times), np.array(np_times)

# %%
# TESTING AREA

check_correctness(python_inner, 100)

# %%
# PLOTTING AREA

def plot_time_vs_size(step=20, max_size=1000, n_samples=20):
    inner_py_times, inner_np_times = get_times_lists(python_inner, step, max_size, n_samples)
    sizes = np.arange(20, max_size + 1, 20)
    plt.plot(sizes, inner_py_times, c='r', lw=2, label="py")
    plt.plot(sizes, inner_np_times, c='b', lw=2, label="np")
    plt.xlim(0, max_size)
    plt.title("Dot product: python vs numpy")
    plt.legend()
    plt.xlabel("size")
    plt.ylabel("time, s")
    plt.grid(ls=":");


plot_time_vs_size()

# %% [markdown]
# On average, `np.dot` is 2-3 times better, than pythonic loops:

# %%
inner_py_times, inner_np_times = get_times_lists(python_inner)
plt.plot(inner_py_times / inner_np_times, lw=2, c='r');
plt.ylim(0, 5)
plt.grid(ls=":")
